# %% [markdown]
# # Lab 1: Getting started with NerworkX (solution)

# %% [markdown]
# ## Exercise 2
# Now do the same for the Actor Network illustrated on the slide. For now let's ignore in which movies the actors were together.
#
# - Create a list
# - Populate Graph
# - Check Number of Nodes (N)
# - Check Number of Edges (L)
# - Display Graph

# %% [markdown]
# Start by importing `pyplot` form `matplotlib` as `plt` and `networkx` as `nx`

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# Let's start by creating a list for our relationships between actors `actorRels` where the relationships between two actors will be in sublists

# %%
actorRels = [
["Marlon Brando", "Al Pacino"],
["Marlon Brando", "Henry Silva"],
["Henry Silva", "Al Pacino"],
["Al Pacino", "Michelle Pfeiffer"]
]
actorRels
# Out:
# [['Marlon Brando', 'Al Pacino'],
#  ['Marlon Brando', 'Henry Silva'],
#  ['Henry Silva', 'Al Pacino'],
#  ['Al Pacino', 'Michelle Pfeiffer']]

# %% [markdown]
# Now let's create and populate our graph, which we will call `actorGraph`
#
# *Remember that nx.Graph is case sensitive so nx.graph won't work.*

# %%
actorGraph = nx.Graph()
actorGraph.add_edges_from(actorRels)

# %% [markdown]
# Let's check whether it has the correct number of nodes and edges.
#
# *The answer should be 4 and 4.*

# %%
print("Edges:", actorGraph.number_of_edges())
print("Nodes:", actorGraph.number_of_nodes())
# Out:
# Edges: 4
# Nodes: 4

# %% [markdown]
# Now let's display the graph.

# %%
nx.draw_networkx(actorGraph)

# %% [markdown]
# Looks good, but the labels are trimmed. Let's try changing the size of the nodes to 10 and the font size to 7.

# %%
nx.draw_networkx(actorGraph, font_size=7, node_size=10)
plt.show()

# %% [markdown]
# Much better!

# %%
print("Congratulations on creating your first network!")
# Out:
# Congratulations on creating your first network!
