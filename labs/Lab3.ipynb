# %% [markdown]
# # Lab 3
#
# This notebook is a slightly revised copy of Chapter 2 tutorial by F. Menczer, S. Forunato, C.A. Davis, *A First Course in Network Science* (Cambridge 2020), available at: https://cambridgeuniversitypress.github.io/FirstCourseNetworkScience/
#
# Contents:
#
# 1. Paths
# 2. Connected components
# 3. Directed paths & components
# 4. Exercises with the dataset of US air traffic network
#
# *Note that many exercises are followed by a block with some `assert` statements. These assertions may be preceded by some setup code. They are provided to give you feedback that you are on the right path -- receiving an `AssertionError` probably means you've done something wrong.*
#
# As always, we start with importing NetworkX:

# %%
import networkx as nx

# %% [markdown]
# Then we create a new undirected graph with four nodes:

# %%
G = nx.Graph()
edges = [[1,2], [2,3], [1,3], [1,4]]
G.add_edges_from(edges)
nx.draw(G, with_labels=True)

# %% [markdown]
# # 1. Paths

# %% [markdown]
# A *path* in a network is a sequence of edges connecting two nodes. In this simple example, we can easily see that there is indeed at least one path that connects nodes 3 and 4. We can verify this with NetworkX:

# %%
nx.has_path(G, 3, 4)
# Out:
# True

# %% [markdown]
# There can be more than one path between two nodes. Again considering nodes 3 and 4, there are two such "simple" paths:

# %%
list(nx.all_simple_paths(G, 3, 4))
# Out:
# [[3, 2, 1, 4], [3, 1, 4]]

# %% [markdown]
# A simple path is one without any cycles. If we allowed cycles, there would be infinitely many paths because one could always just go around the cycle as many times as desired.
#
# We are often most interested in *shortest* paths. In an unweighted network, the shortest path is the one with the fewest edges. We can see that of the two simple paths between nodes 3 and 4, one is shorter than the other. We can get this shortest path with a single NetworkX function:

# %%
nx.shortest_path(G, 3, 4)
# Out:
# [3, 1, 4]

# %% [markdown]
# If you only care about the path length, there's a function for that too:

# %%
nx.shortest_path_length(G, 3, 4)
# Out:
# 2

# %% [markdown]
# Note that a path length is defined here by the number of *edges* in the path, not the number of nodes, which implies
#
#     nx.shortest_path_length(G, u, v) == len(nx.shortest_path(G, u, v)) - 1
#
# for nodes $u$ and $v$.

# %% [markdown]
# ## 2. Connected components
#
# In the simple network above, we can see that for *every* pair of nodes, we can find a path connecting them. This is the definition of a *connected* graph. We can check this property for a given graph:

# %%
nx.is_connected(G)
# Out:
# True

# %% [markdown]
# Not every graph is connected:

# %%
G = nx.Graph()
G.add_edges_from([[1,2], [2,3], [3,1]])
G.add_edge(4,5)
nx.draw(G, with_labels=True)

# %%
nx.is_connected(G)
# Out:
# False

# %% [markdown]
# And NetworkX will raise an error if you ask for a path between nodes where none exists:

# %%
nx.has_path(G, 3, 5)
# Out:
# False

# %%
nx.shortest_path(G, 3, 5)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNoPath                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nx.shortest_path(G, 3, 5)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 20:3, in argmap_shortest_path_17(G, source, target, weight, method, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/miniconda3/envs/kraken_test/lib/python3.10/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/miniconda3/envs/kraken_test/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/generic.py:183, in shortest_path(G, source, target, weight, method)
#     180 else:
#     181     # Find shortest source-target path.
#     182     if method == "unweighted":
# --> 183         paths = nx.bidirectional_shortest_path(G, source, target)
#     184     elif method == "dijkstra":
#     185         _, paths = nx.bidirectional_dijkstra(G, source, target, weight)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 24:3, in argmap_bidirectional_shortest_path_21(G, source, target, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/miniconda3/envs/kraken_test/lib/python3.10/site-packages/networkx/utils/backends.py:967, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     965     if backend is not None and backend != "networkx":
#     966         raise ImportError(f"'{backend}' backend is not installed")
# --> 967     return self.orig_func(*args, **kwargs)
#     969 # Use `backend_name` in this function instead of `backend`.
#     970 # This is purely for aesthetics and to make it easier to search for this
#     971 # variable since "backend" is used in many comments and log/error messages.
#     972 backend_name = backend
#
# File ~/miniconda3/envs/kraken_test/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/unweighted.py:250, in bidirectional_shortest_path(G, source, target)
#     247     raise nx.NodeNotFound(f"Target {target} is not in G")
#     249 # call helper to do the real work
# --> 250 results = _bidirectional_pred_succ(G, source, target)
#     251 pred, succ, w = results
#     253 # build path from pred+w+succ
#
# File ~/miniconda3/envs/kraken_test/lib/python3.10/site-packages/networkx/algorithms/shortest_paths/unweighted.py:318, in _bidirectional_pred_succ(G, source, target)
#     315                 if w in pred:  # found path
#     316                     return pred, succ, w
# --> 318 raise nx.NetworkXNoPath(f"No path between {source} and {target}.")
#
# NetworkXNoPath: No path between 3 and 5.

# %% [markdown]
# Visually, we can identify two connected components in our graph. Let's verify this with NetworkX function `number_connected_components`:

# %%
nx.number_connected_components(G)
# Out:
# 2

# %% [markdown]
# We can inspect which nodes are in which component with the `nx.connected_components()` function. It takes a graph and returns a list of sets of node names, one such set for each connected component. Verify that the two sets in the following list correspond to the two connected components in the drawing of the graph above:

# %%
list(nx.connected_components(G))
# Out:
# [{1, 2, 3}, {4, 5}]

# %% [markdown]
# In case you're not familiar with Python sets, they are collections of items without duplicates.
# These are useful for collecting node names because node names should be unique. Read more: https://www.w3schools.com/python/python_sets.asp
#
# We can get the number of items in a set with the `len` function:

# %%
components = list(nx.connected_components(G))
len(components[0])
# Out:
# 3

# %% [markdown]
# We often care about the largest connected component, which is sometimes referred to as the *core* of the network. We can make use of Python's builtin `max` function in order to obtain the largest connected component. By default, Python's `max` function sorts things in lexicographic (i.e. alphabetical) order, which is not helpful here. We want the maximum connected component when sorted in order of their sizes, so we pass `len` as a key function:

# %%
max(nx.connected_components(G), key=len)
# Out:
# {1, 2, 3}

# %% [markdown]
# While it's often enough to just have the list of node names, sometimes we need the actual subgraph consisting of the largest connected component. One way to get this is to pass the list of node names to the `G.subgraph()` function:

# %%
core_nodes = max(nx.connected_components(G), key=len)
core = G.subgraph(core_nodes)

nx.draw(core, with_labels=True)

# %% [markdown]
# Those of you using tab-completion will also notice a `nx.connected_component_subgraphs()` function. This can also be used to get the core subgraph but the method shown is more efficient when you only care about the largest connected component.

# %% [markdown]
# # 3. Directed paths & components
#
# Let's extend these ideas about paths and connected components to directed graphs.

# %%
D = nx.DiGraph()
D.add_edges_from([
    (1,2),
    (2,3),
    (3,2), (3,4), (3,5),
    (4,2), (4,5), (4,6),
    (5,6),
    (6,4),
])
nx.draw(D, with_labels=True)

# %% [markdown]
# ### Directed paths
#
# We know that in a directed graph, an edge from an arbitrary node $u$ to an arbitrary node $v$ does not imply that an edge exists from $v$ to $u$. Since paths must follow edge direction in directed graphs, the same asymmetry applies for paths. Observe that this graph has a path from 1 to 4, but not in the reverse direction.

# %%
nx.has_path(D, 1, 4)
# Out:
# True

# %%
nx.has_path(D, 4, 1)
# Out:
# False

# %% [markdown]
# The other NetworkX functions dealing with paths take this asymmetry into account as well:

# %%
nx.shortest_path(D, 2, 5)
# Out:
# [2, 3, 5]

# %%
nx.shortest_path(D, 5, 2)
# Out:
# [5, 6, 4, 2]

# %% [markdown]
# Since there is no edge from 5 to 3, the shortest path from 5 to 2 cannot simply backtrack the shortest path from 2 to 5 -- it has to go a longer route through nodes 6 and 4.

# %% [markdown]
# ### Directed components

# %% [markdown]
# Directed networks have two kinds of connectivity. *Strongly connected* means that there exists a directed path between every pair of nodes, i.e., that from any node we can get to any other node while following edge directionality. Think of cars on a network of one-way streets: they can't drive against the flow of traffic.

# %%
nx.is_strongly_connected(D)
# Out:
# False

# %% [markdown]
# *Weakly connected* means that there exist a path between every pair of nodes, regardless of direction. Think about pedestrians on a network of one-way streets: they walk on the sidewalks so they don't care about the direction of traffic.

# %%
nx.is_weakly_connected(D)
# Out:
# True

# %%
# This will raise an error
nx.is_connected(D)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# Cell In[25], line 2
#       1 # This will raise an error
# ----> 2 nx.is_connected(D)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 41:3, in argmap_is_connected_37(G, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/miniconda3/envs/kraken_test/lib/python3.10/site-packages/networkx/utils/decorators.py:91, in not_implemented_for.<locals>._not_implemented_for(g)
#      87 def _not_implemented_for(g):
#      88     if (mval is None or mval == g.is_multigraph()) and (
#      89         dval is None or dval == g.is_directed()
#      90     ):
# ---> 91         raise nx.NetworkXNotImplemented(errmsg)
#      93     return g
#
# NetworkXNotImplemented: not implemented for directed type

# %% [markdown]
# When working with directed graphs, instead of using `nx.connected_components` we use `nx.weakly_connected_components` and `nx.strongly_connected_components`:

# %%
list(nx.weakly_connected_components(D))
# Out:
# [{1, 2, 3, 4, 5, 6}]

# %%
list(nx.strongly_connected_components(D))
# Out:
# [{2, 3, 4, 5, 6}, {1}]

# %% [markdown]
# ## 4. Exercises with the dataset of US air traffic network
#
# In the `data` folder you will find a network of US air travel routes. This dataset also comes from F. Menczer, S. Forunato, C.A. Davis, *A First Course in Network Science* (Cambridge 2020), available at: https://cambridgeuniversitypress.github.io/FirstCourseNetworkScience/
#
# The file is a compressed gzip file (gz). Gzip is a file format used for file compression and decompression. When decompressed, it contains one graphML file (graphml).  GraphML is an XML-based file format for graphs. It is a common format for exchanging graph structure data. If you want to inspect it, you can open it with Oxygen XML editor just like any other XML file.
#
# In NetworkX we have a fuction `read_graphml`, which can also open compressed gzip files containgin graphML files if named `file.graphml.gz`. Read more: https://networkx.org/documentation/stable/reference/readwrite/generated/networkx.readwrite.graphml.read_graphml.html

# %%
G = nx.read_graphml('data/openflights_usa.graphml.gz')

# %% [markdown]
# The nodes in this graph are airports, represented by their [IATA codes](https://en.wikipedia.org/wiki/List_of_airports_by_IATA_code:_A); two nodes are connected with an edge if there is a scheduled flight directly connecting these two airports.
#
# We'll assume this graph to be undirected since a flight in one direction usually means there is a return flight.
#
# Thus this graph has edges
# ```
# [('HOM', 'ANC'), ('BGM', 'PHL'), ('BGM', 'IAD'), ...]
# ```
# where ANC is Anchorage, IAD is Washington Dulles, etc.
#
# These nodes also have **attributes** associated with them, containing additional information about the airports:

# %%
G.nodes['IND']
# Out:
# {'name': 'Indianapolis International Airport',
#  'latitude': 39.7173,
#  'longitude': -86.294403,
#  'IATA': 'IND'}

# %% [markdown]
# Node attributes are stored as a dictionary, so the values can be accessed individually as such:

# %%
G.nodes['IND']['name']
# Out:
# 'Indianapolis International Airport'

# %% [markdown]
# ### Exercise 1
#
# Is there a direct flight between Indianapolis and Fairbanks, Alaska (FAI)? A direct flight is one with no intermediate stops.

# %%
# Type your answer and function here.

# %% [markdown]
# ### Exercise 2
#
# If I wanted to fly from Indianapolis to Fairbanks, Alaska what would be an itinerary with the fewest number of flights?

# %%
# Type your answer and function here.

# %% [markdown]
# ### Exercise 3
#
# Is it possible to travel from any airport in the US to any other airport in the US, possibly using connecting flights? In other words, does there exist a path in the network between every possible pair of airports?

# %%
# Type your answer and function here.
